# %%
import cv2
import matplotlib.pyplot as plt
import json
import os
from PIL import Image,ImageFont,ImageDraw
from googletrans import Translator
from sys import stdout

# %%
path_dir = "./train/labels/나무/"
label = []

for i in range(7,14):
    temp = []
    file_tree = os.listdir(path_dir+str(i))
    for index,dir in enumerate(file_tree):
        with open(path_dir +str(i)+'/'+ dir) as f:
            json_object = json.load(f)
            temp.append(json_object['annotations'])
            temp[index]['img_path'] = json_object['meta']['img_path']
            temp[index]['img_path'] = temp[index]['img_path'].replace('../../../../','./train/')
    label.extend(temp)

# %%
row = label[2]
print(row)
# Out:
# {'anno_id': 'nsw1jb4d6wdsm4gq15mph', 'class': '나무', 'bbox_count': 27, 'bbox': [{'label': '나무전체', 'x': 478, 'y': 789, 'w': 450, 'h': 490}, {'label': '기둥', 'x': 606, 'y': 954, 'w': 143, 'h': 240}, {'label': '수관', 'x': 478, 'y': 789, 'w': 381, 'h': 305}, {'label': '가지', 'x': 745, 'y': 1052, 'w': 183, 'h': 82}, {'label': '뿌리', 'x': 592, 'y': 1192, 'w': 218, 'h': 87}, {'label': '나뭇잎', 'x': 534, 'y': 925, 'w': 37, 'h': 75}, {'label': '나뭇잎', 'x': 580, 'y': 872, 'w': 66, 'h': 71}, {'label': '나뭇잎', 'x': 666, 'y': 922, 'w': 42, 'h': 45}, {'label': '나뭇잎', 'x': 678, 'y': 821, 'w': 37, 'h': 59}, {'label': '나뭇잎', 'x': 736, 'y': 875, 'w': 36, 'h': 63}, {'label': '꽃', 'x': 936, 'y': 1111, 'w': 74, 'h': 78}, {'label': '꽃', 'x': 1037, 'y': 1099, 'w': 88, 'h': 86}, {'label': '꽃', 'x': 1160, 'y': 1104, 'w': 77, 'h': 75}, {'label': '열매', 'x': 741, 'y': 829, 'w': 33, 'h': 38}, {'label': '열매', 'x': 505, 'y': 863, 'w': 51, 'h': 49}, {'label': '열매', 'x': 786, 'y': 947, 'w': 47, 'h': 53}, {'label': '그네', 'x':
# ...

# %%
translator = Translator()

img = cv2.imread(row['img_path'])

for a in row['bbox']:
    w = a['w']
    h = a['h']
    x = a['x']
    y = a['y']
    cv2.rectangle(
      img,
      (int(x), int(y)),
      (int(x + w), int(y + h)),
      color=(0, 255, 0),
      thickness=2
    )
    name = translator.translate(a['label']).text
    ((label_width, label_height), _) = cv2.getTextSize(
        name,
        fontFace=cv2.FONT_HERSHEY_PLAIN,
        fontScale=1.75,
        thickness=2
    )
    cv2.rectangle(
      img,
      (int(x), int(y)),
      (int(x + label_width + label_width * 0.05), int(y + label_height + label_height * 0.25)),
      color=(0, 255, 0),
      thickness=cv2.FILLED
    )
    cv2.putText(
      img,
      name,
      org=(int(x), int(y + label_height + label_height * 0.25)), # bottom left
      fontFace=cv2.FONT_HERSHEY_PLAIN,
      fontScale=1.75,
      color=(255, 255, 255),
      thickness=2
    )



plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 1279.5, 1279.5, -0.5)

# %%
translator = Translator()

def create_dataset(categories):
    label_path = './datasets/custom/labels/train2017/'
    img_path = './datasets/custom/images/train2017/'
    
    for count, img in enumerate(label):
        images_name = f"{img['anno_id']}.jpeg"
        imgdata = Image.open(img['img_path'])
        imgdata.save(img_path+images_name, "JPEG")
        
        label_name= f"{img['anno_id']}.txt"
        
        with(open(label_path+label_name,mode="w")) as label_file:
            for a in img['bbox']:
                category_idx = categories.index(a['label'])
                
                x1,y1 = int(a['x']),int(a['y'])
                x2,y2 = int(a['x']+a['w']),int(a['y']+a['h'])
                
                bbox_width = x2 - x1
                bbox_height = y2 - y1
                
                label_file.write(
                    f"{category_idx} {x1+bbox_width / 2} {y1 + bbox_height / 2} {bbox_width} {bbox_height}\n"
                )
        stdout.write("\r===== "+str(count)+"/"+str(len(label)-1)+" progressed=====")
        stdout.flush()

# %%
categories = [
"집전체",
"지붕",
"집벽",
"문",
"창문",
"굴뚝",
"연기", #보류
"울타리",
"길",
"연못",
"산",
"나무",
"꽃",
"잔디",
"태양",
"나무전체",
"기둥",
"수관",
"가지",
"뿌리",
"나뭇잎",
"꽃",
"열매",
"그네",
"새",
"다람쥐",
"구름",
"달",
"별",
"사람전체",
"머리",
"얼굴",
"눈",
"코",
"입",
"귀",
"머리카락",
"목",
"상체",
"팔",
"손",
"다리",
"발",
"단추",
"주머니",
"운동화",
"여자구두",
"남자구두"
]


# categories = [
# "whole house",
# "roof",
# "house wall",
# "door",
# "window",
# "Chimney",
# "smoke", #보류
# "fence",
# "road",
# "pond",
# "mountain",
# "tree",
# "flower",
# "grass",
# "Sun",
# "Entire tree",
# "Pillar",
# "water tube",
# "Branch",
# "Root",
# "leaf",
# "Flower",
# "Fruit",
# "Swing",
# "bird",
# "squirrel",
# "cloud",
# "moon",
# "star",
# "whole person",
# "head",
# "face",
# "Eye",
# "nose",
# "mouth",
# "ear",
# "hair",
# "neck",
# "upper body",
# "arm",
# "hand",
# "Leg",
# "foot",
# "button",
# "pocket",
# "running shoes",
# "women's shoes",
# "men's shoes"
# ]

# %%
create_dataset(categories)
# Out:
# ===== 28/999 progressed=====
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 create_dataset(categories)
#
# Cell In[25], line 16, in create_dataset(categories)
#      14 with(open(label_path+label_name,mode="w")) as label_file:
#      15     for a in img['bbox']:
# ---> 16         name = translator.translate(a['label']).text
#      17         category_idx = categories.index(name)
#      19         x1,y1 = int(a['x']),int(a['y'])
#
# File ~/opt/anaconda3/envs/hackathon/lib/python3.8/site-packages/googletrans/client.py:194, in Translator.translate(self, text, dest, src)
#     191         raise ValueError('invalid destination language')
#     193 origin = text
# --> 194 data, response = self._translate(text, dest, src)
#     196 token_found = False
#     197 square_bracket_counts = [0, 0]
#
# ...
